# %%
import scrapy
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url = "https://www.walmart.ca"

# %%
page = urlopen(url)

# %%
page = requests.get("https://www.bestbuy.ca/en-ca/product/hp-15-6-laptop-jet-black-intel-core-i3-1115g4-512gb-ssd-8gb-ram-windows-11/16021496")

# %%
page = requests.get("https://www.google.com")

# %%
page

# %%
html_bytes = page.read()
html = html_bytes.decode("utf-8")

# %%
print(html)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 						<!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en-CA" lang="en-CA" prefix="og: http://ogp.me/ns#" class="no-js" data-layout-name="220712_black-bird">
# <head>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <meta charset="utf-8" />
# <link rel="canonical" href="https://www.apple.com/ca/" />
#
#
#
# ...
